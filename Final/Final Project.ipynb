# %%
Names = "Scott Duncan", "Aiden Wells"

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
acc = pd.read_csv('/home/duncans1/Final/ACC_AUX.CSV')
per = pd.read_csv('/home/duncans1/Final/PER_AUX.CSV')
veh = pd.read_csv('/home/duncans1/Final/VEH_AUX.CSV')

# %%
acc = pd.DataFrame(acc)
per = pd.DataFrame(per)
veh = pd.DataFrame(veh)

data = result = pd.concat([acc,per,veh], axis=1, sort=False)

data.dropna()
# Out:
#          YEAR  STATE   ST_CASE  COUNTY  FATALS  A_CRAINJ  A_REGION  A_RU  \
# 0      2015.0    1.0   10001.0   127.0     1.0       1.0       4.0   1.0
# 1      2015.0    1.0   10002.0    83.0     1.0       1.0       4.0   1.0
# 2      2015.0    1.0   10003.0    11.0     1.0       1.0       4.0   1.0
# 3      2015.0    1.0   10004.0    45.0     1.0       1.0       4.0   1.0
# 4      2015.0    1.0   10005.0    45.0     1.0       1.0       4.0   2.0
# 5      2015.0    1.0   10006.0   111.0     1.0       1.0       4.0   1.0
# 6      2015.0    1.0   10007.0    89.0     1.0       1.0       4.0   2.0
# 7      2015.0    1.0   10008.0    73.0     1.0       1.0       4.0   2.0
# 8      2015.0    1.0   10009.0   117.0     1.0       1.0       4.0   2.0
# 9      2015.0    1.0   10010.0    33.0     1.0       1.0       4.0   1.0
# 10     2015.0    1.0   10011.0    83.0     1.0       1.0       4.0   2.0
# 11     2015.0    1.0   10012.0    95.0     1.0       1.0       4.0   2.0
# ...
